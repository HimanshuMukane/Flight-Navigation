# %%
import matplotlib.pyplot as plt

# Define the points for the first set
points1 = [(40.7128, -74.006), (40.84967033430713, -78.67586478629836), (40.79709517970596, -83.35164463056793), (40.555715879307975, -88.00686795595834), (40.128443476304135, -92.61605962755559), (39.52029944740094, -97.15591464581742), (38.738153336520206, -101.60623958380341), (37.79038880558262, -105.95058555957014), (36.68653433340621, -110.17655028608988), (35.436893089900316, -114.27577549039238), (34.0522, -118.24370000000002)]

# Define the points for the second set
points2 = [(39.7128, -75.006), (33.0522, -119.24370000000002), (33.0522, -119.2437)]

# Split points into X and Y coordinates
x_coords1, y_coords1 = zip(*points1)
x_coords2, y_coords2 = zip(*points2)

# Plot the points
plt.figure(figsize=(10, 10))
plt.plot(x_coords1, y_coords1, marker='o', linestyle='-', label='Points 1')
plt.plot(x_coords2, y_coords2, marker='o', linestyle='-', label='Points 2')
plt.title('Plot of Given Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.legend()
plt.show()
